# %%
# area or stack plot 
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
area = [5,2,1,3,1]
area1 = [1,2,5,3,2]
area2 = [4,3,4,5,3]
l = ['area1', 'area2', 'area3']
plt.stackplot(x,area, area1, area2, labels=l, baseline= 'sym')
plt.legend(loc = 2)
plt.show()
